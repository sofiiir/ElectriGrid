# %% [markdown]
# # CAISO Locational Marginal Pricing (LMP) Data Exploration
#
# Source: https://www.gridstatus.io/live

# %%
# load necessary libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ## CAISO LMP Real Time 5 Min
# The LMP Real time 5 minute dataset is the only dataset that includes the node information necessary for understanding the different loads and LMP for different regions. This dataset is 11,000,000,000 rows. The free version of the Grid Status account only allows for a download of 500,000 rows.
#
# Note: Altering the time frame is not possible without having the paid version.
#
# Source: https://www.gridstatus.io/datasets/caiso_system_load_and_resource_schedules_real_time_5_min

# %%
# must install gridstatusio to the environment
from gridstatusio import GridStatusClient

# recommended: set GRIDSTATUS_API_KEY as an
# environment variable instead of hardcoding
client = GridStatusClient("4f4d18adff9745899afb96c934dcd947")

# fetch data as pandas DataFrame
df = client.get_dataset(
  dataset="caiso_lmp_real_time_5_min",
  start="2026-01-17",
  end="2026-01-20",
  timezone="market",
)
# Out:
# 2026-01-19 22:44:14 - INFO - Fetching Page 1...
# 2026-01-19 22:44:14 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_lmp_real_time_5_min/query
# 2026-01-19 22:44:14 - INFO - Params: {'start_time': Timestamp('2026-01-17 00:00:00'), 'end_time': Timestamp('2026-01-20 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 9
#       6 client = GridStatusClient("4f4d18adff9745899afb96c934dcd947")
#       8 # fetch data as pandas DataFrame
# ----> 9 df = client.get_dataset(
# ...

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined
